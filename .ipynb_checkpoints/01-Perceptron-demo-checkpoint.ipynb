# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score

# %%
df = pd.read_csv("Datasets/placement.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
y_pred = p.predict(X)

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# C:\Users\saadt\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
accuracy = accuracy_score(y, y_pred)
print(f"Accuracy: {accuracy}\n")
# Out:
# Accuracy: 0.75

# %%
# Generate confusion matrix
conf_matrix = confusion_matrix(y, y_pred)
print("Confusion Matrix:")
print(conf_matrix, "\n")
# Out:
# Confusion Matrix:
# [[39 11]
#  [14 36]]

# %%
# Calculate precision
precision = precision_score(y, y_pred)
print(f"Precision: {precision}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Calculate precision
# ----> 2 precision = precision_score(y, y_pred)
#       3 print(f"Precision: {precision}\n")
#
# NameError: name 'precision_score' is not defined

# %%
# Calculate recall
recall = recall_score(y, y_pred)
print(f"Recall: {recall}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Calculate recall
# ----> 2 recall = recall_score(y, y_pred)
#       3 print(f"Recall: {recall}\n")
#
# NameError: name 'recall_score' is not defined

# %%
# Calculate F1 score
f1 = f1_score(y, y_pred)
print(f"F1 Score: {f1}\n")

# %%
# Classification report for precision, recall, and F1 score
class_report = classification_report(y, y_pred)
print("Classification Report:")
print(class_report)

# %%
# Classification report for precision, recall, and F1 score
class_report = classification_report(y, y_pred)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76        50
#            1       0.77      0.72      0.74        50
#
#     accuracy                           0.75       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.75      0.75      0.75       100

# %%
from mlxtend.plotting import plot_decision_regions

# Plot decision regions
plot_decision_regions(X.values, y.values, clf=p, legend=2)
plt.xlabel('CGPA')
plt.ylabel('Resume Score')
plt.title('Decision Region using Perceptron')
plt.show()
# Out:
# C:\Users\saadt\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
